# %%
import warnings
warnings.filterwarnings('ignore')
import os as os
os.chdir('C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/')
# %matplotlib inline
from WildAlertpy import WRMDalert as alert
from WildAlertpy import read_data as read_data
from WildAlertpy import anomaly as an
data_path = 'C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/wildalert exports/'
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.style as style
import numpy as np
import math
#style.use('fivethirtyeight')
plt.rcParams['font.family'] = 'Times New Roman'
sns.set_context("notebook", font_scale=1.30, rc={"lines.linewidth": 0.8})

# %% [markdown]
# ## Shearwaters

# %%
# %%time
an.plot_multiple_anomaly_timelines(
    filenames=['C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/sporadic/shearwaters-in-florida', 
               ],
    window_size=10,
    sigma=2,
    grey_periods=[('2024-06-04', '2024-07-25')],
    disease_labels=["Strandings due to adverse weather"],
    plot_top_axis=True, 
    plot_start_date="2015-01-01",
    save=True,
    highlight_events = True,
    save_path = "Shearwaters stranding due to adverse weather in Florida.png"
)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Fleiss' Kappa: 0.358
# Cohen's Kappa (IOF vs AE): 0.214
# C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/sporadic/shearwaters-in-florida date range: 2012-06-24 00:00:00 to 2025-06-29 00:00:00
# C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/sporadic/shearwaters-in-florida — t-test p=0.0071, permutation p=0.0000
# Saved to: Shearwaters stranding due to adverse weather in Florida.png
# CPU times: total: 26.2 s
# Wall time: 24 s
# {'C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/sporadic/shearwaters-in-florida': {'t_test_pval': np.float64(0.00714651367236496),
#   'permutation_pval': 0.0}}

# %% [markdown]
# ## Shorebirds with Neurologic disease Brevetoxicosis

# %%
# %%time
an.plot_multiple_anomaly_timelines(
    filenames=['C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/shorebirds-with-neurologic-disease-in-florida', 
               ],
    window_size=10,
    sigma=2,
    grey_periods=[('2024-08-15', '2024-09-15')],
    disease_labels=["Brevetoxicosis"],
    plot_top_axis=True, 
    plot_start_date="2015-01-01",
    save=True,
    highlight_events = True,
    save_path = "Shorebirds with neurologic disease and brevetoxicosis.png"
)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Fleiss' Kappa: 0.176
# Cohen's Kappa (IOF vs AE): 0.073
# C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/shorebirds-with-neurologic-disease-in-florida date range: 2015-01-11 00:00:00 to 2025-07-27 00:00:00
# Saved to: Shorebirds with neurologic disease and brevetoxicosis.png
# CPU times: total: 24.3 s
# Wall time: 25.5 s

# %% [markdown]
# ## Seabirds with brevetoxicosis in Florida

# %%
# %%time
an.plot_multiple_anomaly_timelines(
    filenames=['C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/seabirds-with-neurologic-disease-in-florida', 
               ],
    window_size=10,
    sigma=2,
    grey_periods=[('2024-06-15', '2024-07-15')],
    disease_labels=["Brevetoxicosis"],
    plot_top_axis=True, 
    plot_start_date="2015-01-01",
    save=True,
    highlight_events = True,
    save_path = "Seabirds with neurologic disease and brevetoxicosis.png"
)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Fleiss' Kappa: 0.259
# Cohen's Kappa (IOF vs AE): 0.234
# C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/seabirds-with-neurologic-disease-in-florida date range: 2015-01-04 00:00:00 to 2025-04-27 00:00:00
# Saved to: Seabirds with neurologic disease and brevetoxicosis.png
# CPU times: total: 27.7 s
# Wall time: 27.6 s

# %% [markdown]
# ## Green Sea Turtles and cold stunning

# %%
# %%time
an.plot_multiple_anomaly_timelines(
    filenames=['C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/sporadic/green-sea-turtles', 
               ],
    window_size=10,
    sigma=2,
    grey_periods=[('2025-01-10', '2025-01-31')],
    disease_labels=["Cold-Stunning"],
    plot_top_axis=True, 
    plot_start_date="2015-01-01",
    save=True,
    highlight_events = True,
    save_path = "Green Sea turtles and cold-stunning.png"
)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Fleiss' Kappa: 0.238
# Cohen's Kappa (IOF vs AE): 0.361
# C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/sporadic/green-sea-turtles date range: 2015-02-01 00:00:00 to 2025-04-27 00:00:00
# Saved to: Green Sea turtles and cold-stunning.png
# CPU times: total: 24 s
# Wall time: 24.7 s

# %% [markdown]
# ## Brown Pelican with Nutritional disease

# %%
# %%time
an.plot_multiple_anomaly_timelines(
    filenames=['C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/sporadic/brown-pelican-with-nutritional-disease-in-california', 
               ],
    window_size=10,
    sigma=2,
    grey_periods=[('2024-04-15', '2024-05-05')],
    disease_labels=["Starvation event with physical injuries (fishing gear related injuries)"],
    plot_top_axis=True, 
    plot_start_date="2015-01-01",
    save=True,
    highlight_events = True,
    save_path = "Brown Pelicans with nutritional disease (starvation event).png"
)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Fleiss' Kappa: 0.306
# Cohen's Kappa (IOF vs AE): 0.381
# C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/sporadic/brown-pelican-with-nutritional-disease-in-california date range: 2013-07-14 00:00:00 to 2025-06-22 00:00:00
# Saved to: Brown Pelicans with nutritional disease (starvation event).png
# CPU times: total: 24 s
# Wall time: 26.6 s

# %% [markdown]
# ## Sanderlings with Neurological disease HPAI

# %%
# %%time
an.plot_multiple_anomaly_timelines(
    filenames=['C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/shorebirds-with-neurologic-disease-in-california', 
               ],
    window_size=10,
    sigma=2,
    grey_periods=[('2022-12-01', '2023-02-28'), ('2023-04-01', '2023-04-30'), ('2023-12-01', '2024-01-31'),  ('2025-01-01', '2025-02-28'), 
    ('2025-01-25', '2025-02-01')],
    disease_labels=["HPAI case reported in USDA records", "HPAI case reported in USDA records","HPAI case reported in USDA records","HPAI case reported in USDA records",'HPAI detection in Sanderlings'],
    plot_top_axis=True, 
    plot_start_date="2022-01-01",
    save=True,
    save_path = "Shorebirds with neurologic disease and HPAI in California.png"
)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Fleiss' Kappa: 0.261
# Cohen's Kappa (IOF vs AE): 0.401
# C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/shorebirds-with-neurologic-disease-in-california date range: 2015-01-11 00:00:00 to 2025-07-20 00:00:00
# Saved to: Shorebirds with neurologic disease and HPAI in California.png
# CPU times: total: 23.7 s
# Wall time: 24.1 s

# %%
# %%time
an.plot_multiple_anomaly_timelines(
    filenames=['C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/raptors-with-neurologic-disease-in-california', 
               ],
    window_size=10,
    sigma=2,
    grey_periods=[('2022-07-01', '2023-04-30'), ('2023-07-01', '2023-08-31'),  ('2023-10-01', '2024-04-30'), ('2024-11-01', '2025-03-31')],
    disease_labels=['HPAI case reported in USDA records', 'HPAI case reported in USDA records', 'HPAI case reported in USDA records', 'HPAI case reported in USDA records'],
    plot_top_axis=True, 
    plot_start_date="2022-01-01",
    save=True,
    save_path = "Raptors with neurologic disease and HPAI in California.png"
)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Fleiss' Kappa: 0.216
# Cohen's Kappa (IOF vs AE): 0.230
# C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/raptors-with-neurologic-disease-in-california date range: 2015-01-04 00:00:00 to 2025-07-20 00:00:00
# Saved to: Raptors with neurologic disease and HPAI in California.png
# CPU times: total: 26.5 s
# Wall time: 30 s

# %%
# %%time
an.plot_multiple_anomaly_timelines(
    filenames=['C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/raptors-with-neurologic-disease-in-florida', 
               ],
    window_size=10,
    sigma=2,
    grey_periods=[('2022-01-01', '2023-01-31'), ('2023-03-01', '2023-03-31'),  ('2023-11-01', '2024-04-30'), ('2024-06-01', '2025-01-31'), ('2025-03-01', '2025-03-31')],
    disease_labels=['HPAI case reported in USDA records', 'HPAI case reported in USDA records', 'HPAI case reported in USDA records', 'HPAI case reported in USDA records', 'HPAI case reported in USDA records'],
    plot_top_axis=True, 
    plot_start_date="2021-06-01",
    save=True,
    save_path = "Raptors with neurologic disease and HPAI in Florida.png"
)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Fleiss' Kappa: 0.227
# Cohen's Kappa (IOF vs AE): 0.133
# C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/raptors-with-neurologic-disease-in-florida date range: 2015-01-18 00:00:00 to 2025-07-20 00:00:00
# Saved to: Raptors with neurologic disease and HPAI in Florida.png
# CPU times: total: 22.4 s
# Wall time: 24.3 s

# %%
# %%time
an.plot_multiple_anomaly_timelines(
    filenames=['C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/waterfowls-with-neurologic-disease-in-florida', 
               ],
    window_size=10,
    sigma=2,
    grey_periods=[('2022-01-01', '2022-06-30'), 
                  ('2022-08-01', '2022-08-31'),
                  ('2022-10-01', '2022-12-31'),
                  ('2023-03-01', '2023-03-31'),
                  ('2023-05-01', '2023-05-31'),
                  ('2023-11-01', '2024-02-29'),
                  ('2024-11-01', '2025-01-31')],
    disease_labels=['HPAI case reported in USDA records']*7,
    plot_top_axis=True, 
    plot_start_date="2021-06-01",
    save=True,
    save_path = "Waterfowls with neurologic disease Florida and HPAI.png"
)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# Fleiss' Kappa: 0.260
# Cohen's Kappa (IOF vs AE): 0.199
# C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/waterfowls-with-neurologic-disease-in-florida date range: 2015-01-04 00:00:00 to 2025-07-20 00:00:00
# Saved to: Waterfowls with neurologic disease Florida and HPAI.png
# CPU times: total: 25.4 s
# Wall time: 26.6 s

# %%
# Out:
# ['HPAI case reported in USDA records',
#  'HPAI case reported in USDA records',
#  'HPAI case reported in USDA records',
#  'HPAI case reported in USDA records',
#  'HPAI case reported in USDA records',
#  'HPAI case reported in USDA records',
#  'HPAI case reported in USDA records']

# %%
# %%time
an.plot_multiple_anomaly_timelines(
    filenames=['C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/finches-with-ocular-disease-in-california', 
               ],
    window_size=10,
    sigma=2,
    #grey_periods=[('2022-07-01', '2023-04-30'), ('2023-07-01', '2023-08-31'),  ('2023-10-01', '2024-04-30'), ('2024-11-01', '2025-03-31')],
    #disease_labels=['HPAI case reported in USDA records', 'HPAI case reported in USDA records', 'HPAI case reported in USDA records', 'HPAI case reported in USDA records'],
    plot_top_axis=True, 
    plot_start_date="2015-01-01",
    save=True,
    save_path = "Finches with ocular disease and Mycoplasmosis in California.png"
)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Fleiss' Kappa: 0.269
# Cohen's Kappa (IOF vs AE): 0.219
# C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/finches-with-ocular-disease-in-california date range: 2013-01-06 00:00:00 to 2025-07-06 00:00:00
# Saved to: Finches with ocular disease and Mycoplasmosis in California.png
# CPU times: total: 25 s
# Wall time: 25.4 s

# %%
# %%time
an.plot_multiple_anomaly_timelines(
    filenames=['C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/columbidae-with-neruologic-disease-in-california', 
               ],
    window_size=10,
    sigma=2,
    grey_periods=[('2017-03-01', '2017-05-01'), ('2016-08-01', '2016-10-31')],#,  ('2023-10-01', '2024-04-30'), ('2024-11-01', '2025-03-31')],
    disease_labels=['Sarcocystis calchasi', 'Pigeon Paramyxovirus Type 1 (PPMV-1)'],#, 'HPAI case reported in USDA records', 'HPAI case reported in USDA records'],
    plot_top_axis=True, 
    plot_start_date="2015-01-01",
    save=True,
    save_path = "Columbidae with neruologic disease in California.png"
)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fleiss' Kappa: 0.259
# Cohen's Kappa (IOF vs AE): 0.190
# C:/Users/prana/Desktop/directory/WildAlert_AnamolyModels/data/paper_exports/endemic/columbidae-with-neruologic-disease-in-california date range: 2013-01-06 00:00:00 to 2025-06-29 00:00:00
# Saved to: Columbidae with neruologic disease in California.png
# CPU times: total: 24.8 s
# Wall time: 25.7 s
